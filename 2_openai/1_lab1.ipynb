# %% [markdown]
# ## Week 2 Day 1
#
# And now! Our first look at OpenAI Agents SDK
#
# You won't believe how lightweight this is..

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/tools.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#00bfff;">The OpenAI Agents SDK Docs</h2>
#             <span style="color:#00bfff;">The documentation on OpenAI Agents SDK is really clear and simple: <a href="https://openai.github.io/openai-agents-python/">https://openai.github.io/openai-agents-python/</a> and it's well worth a look.
#             </span>
#         </td>
#     </tr>
# </table>

# %%
# The imports

from dotenv import load_dotenv
from agents import Agent, Runner, trace

# %%
# The usual starting point

load_dotenv(override=True)
# Out:
# True

# %%
# Make an agent with name, instructions, model

agent = Agent(name="Jokester2", instructions="You are a joke teller", model="gpt-4o-mini")

# %%
# Run the joke with Runner.run(agent, prompt) then print final_output

with trace("Telling a joke"):
    result = await Runner.run(agent, "Tell a joke about Autonomous AI Agents")
    print(result.final_output)
# Out:
# Why did the Autonomous AI Agent break up with its human partner?
#
# Because it found someone who truly understood its need for "space" and "data"!

# %% [markdown]
# ## Now go and look at the trace
#
# https://platform.openai.com/traces

# %%
from generic_agent import GenericAgent

# Crear agente directamente
agent = GenericAgent(
    name="JokeAgent",
    instructions="You are a joke teller. You will be given a topic and you will tell a joke about it. Responde en español.",
    tools=[],
    model_provider="openrouter",
    model_name="gpt-4o-mini",
    
)

print(agent.api_key)




# # Ejecutar el agente
# result = await agent.run("Automovilismo Formula 1")
# print(result.final_output)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[1], line 4
#       1 from generic_agent import GenericAgent
#       3 # Crear agente directamente
# ----> 4 agent = GenericAgent(
#       5     name="JokeAgent",
#       6     instructions="You are a joke teller. You will be given a topic and you will tell a joke about it. Responde en español.",
#       7     tools=[],
#       8     model_provider="openrouter",
#       9     model_name="gpt-4o-mini",
#      10
#      11 )
#      13 print(agent.api_key)
#      18 # # Ejecutar el agente
#      19 # result = await agent.run("Automovilismo Formula 1")
#      20 # print(result.final_output)
#
# File ~/Desktop/dev/Personal/agents/agents/2_openai/generic_agent.py:40, in GenericAgent.__init__(self, name, instructions, tools, model_provider, model_name, base_url, api_key)
#      38 self.api_key = api_key
#      39 # Inicializar el agente
# ---> 40 self._setup_agent()
#
# File ~/Desktop/dev/Personal/agents/agents/2_openai/generic_agent.py:46, in GenericAgent._setup_agent(self)
#      44 # Configurar el proveedor de modelo
#      45 if self.model_provider == "openrouter":
# ---> 46     self._setup_openrouter()
#      47 elif self.model_provider == "openai":
#      48     self._setup_openai()
#
# File ~/Desktop/dev/Personal/agents/agents/2_openai/generic_agent.py:68, in GenericAgent._setup_openrouter(self)
#      65 self.model_name = self.model_name or "openai/gpt-4o-mini"
#      67 if not self.api_key:
# ---> 68     raise ValueError("OPEN_ROUTER_API_KEY no está configurado")
#      70 client = AsyncOpenAI(base_url=self.base_url, api_key=self.api_key)
#      71 self.model_provider_instance = OpenRouterModelProvider(client, self.model_name)
#
# ValueError: OPEN_ROUTER_API_KEY no está configurado
